# %% [markdown]
# ### Importing the Dataset

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')

# %% [markdown]
# ### Section 1: Foundational Data Exploration & Manipulation

# %% [markdown]
# ##### 1. Display the last 7 rows of the DataFrame df to get an initial look at the data.

# %%
print(df.tail(7))
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# ##### 2. Print a summary of the DataFrame including the index dtype and column dtypes, non-null values, and memory usage. Comment on what you see

# %%
print(df.info())  # To get the non-null values, memory usage and columns data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# None

# %%
# There are 2 integer type columns(order_id and quantity) and 2 object(text) type columns(choice_description and item_price)
# The memory usage is a bit small
# Since the RangeIndex indicates there are a total of 4622 entries, it means that choice_description is the only column with missing values; 4622-3376 = 1276

# %%
print(df.index.dtype) # Index data type
# Out:
# int64

# %% [markdown]
# ##### 3. Determine how many observations have missing item_price in the dataset.

# %%
print(df["item_price"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ##### 4. Print the names of all columns in the DataFrame

# %%
print(df.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ##### 5. Identify which item_name appears most frequently in the orders

# %%
top_name = (df["item_name"].value_counts().idxmax())
top_count = (df["item_name"].value_counts().max())
print(f"Most Frequent Item Name is {top_name} with a count of {top_count}")
# Out:
# Most Frequent Item Name is Chicken Bowl with a count of 726

# %% [markdown]
# ##### 6. Determine how many distinct item_name values are present in the dataset

# %%
df["item_name"].nunique()
# Out:
# 50

# %% [markdown]
# ##### 7. Create a new DataFrame containing only the rows where the item_name is 'Chicken Bowl'.

# %%
df2 = df[df["item_name"] == "Chicken Bowl"]
print(df2)
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# ...                                                 ...        ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...    $11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...     $8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...     $8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]     $8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $8.75
#
#      Chips and Fresh Tomato Salsa          Izze Nantucket Nectar  \
# 4                    Chicken Bowl  Chicken Bowl     Chicken Bowl
# 5                    Chicken Bowl  Chicken Bowl     Chicken Bowl
# 13                   Chicken Bowl  Chicken Bowl     Chicken Bowl
# 19                   Chicken Bowl  Chicken Bowl     Chicken Bowl
# 26                   Chicken Bowl  Chicken Bowl     Chicken Bowl
# ...                           ...           ...              ...
# 4590                 Chicken Bowl  Chicken Bowl     Chicken Bowl
# 4591                 Chicken Bowl  Chicken Bowl     Chicken Bowl
# 4595                 Chicken Bowl  Chicken Bowl     Chicken Bowl
# 4599                 Chicken Bowl  Chicken Bowl     Chicken Bowl
# 4604                 Chicken Bowl  Chicken Bowl     Chicken Bowl
#
#      Chips and Tomatillo-Green Chili Salsa  Chicken Bowl  ...  \
# 4                             Chicken Bowl  Chicken Bowl  ...
# 5                             Chicken Bowl  Chicken Bowl  ...
# 13                            Chicken Bowl  Chicken Bowl  ...
# 19                            Chicken Bowl  Chicken Bowl  ...
# 26                            Chicken Bowl  Chicken Bowl  ...
# ...                                    ...           ...  ...
# 4590                          Chicken Bowl  Chicken Bowl  ...
# 4591                          Chicken Bowl  Chicken Bowl  ...
# 4595                          Chicken Bowl  Chicken Bowl  ...
# 4599                          Chicken Bowl  Chicken Bowl  ...
# 4604                          Chicken Bowl  Chicken Bowl  ...
#
#      Carnitas Crispy Tacos   Steak Salad Chips and Mild Fresh Tomato Salsa  \
# 4             Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 5             Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 13            Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 19            Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 26            Chicken Bowl  Chicken Bowl                      Chicken Bowl
# ...                    ...           ...                               ...
# 4590          Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 4591          Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 4595          Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 4599          Chicken Bowl  Chicken Bowl                      Chicken Bowl
# 4604          Chicken Bowl  Chicken Bowl                      Chicken Bowl
#
#      Veggie Soft Tacos Carnitas Salad Bowl Barbacoa Salad Bowl         Salad  \
# 4         Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 5         Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 13        Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 19        Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 26        Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# ...                ...                 ...                 ...           ...
# 4590      Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 4591      Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 4595      Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 4599      Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
# 4604      Chicken Bowl        Chicken Bowl        Chicken Bowl  Chicken Bowl
#
#      Veggie Crispy Tacos  Veggie Salad Carnitas Salad
# 4           Chicken Bowl  Chicken Bowl   Chicken Bowl
# 5           Chicken Bowl  Chicken Bowl   Chicken Bowl
# 13          Chicken Bowl  Chicken Bowl   Chicken Bowl
# 19          Chicken Bowl  Chicken Bowl   Chicken Bowl
# 26          Chicken Bowl  Chicken Bowl   Chicken Bowl
# ...                  ...           ...            ...
# 4590        Chicken Bowl  Chicken Bowl   Chicken Bowl
# 4591        Chicken Bowl  Chicken Bowl   Chicken Bowl
# 4595        Chicken Bowl  Chicken Bowl   Chicken Bowl
# 4599        Chicken Bowl  Chicken Bowl   Chicken Bowl
# 4604        Chicken Bowl  Chicken Bowl   Chicken Bowl
#
# [726 rows x 55 columns]

# %% [markdown]
# ##### 8. The 'item_price' column is currently a string (e.g., '$2.39'). Convert it to a float type. You'll need to remove the dollar sign and then convert the data type.

# %%
df["item_price"] = df["item_price"].str.replace("$", "").astype(float)
print(df["item_price"])
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ##### 9. After converting 'item_price' to a numerical type, calculate the average item_price across all orders.

# %%
avg = df["item_price"].mean()
print(f"Average item_price:",{avg})
# Out:
# Average item_price: {np.float64(7.464335785374297)}

# %% [markdown]
# ##### 10. Determine the total number of unique orders in the dataset based on the order_id column.

# %%
print(f"Total unique orders", df["order_id"].nunique())
# Out:
# Total unique orders 1834

# %% [markdown]
# ##### Section 2

# %% [markdown]
# ##### Total Revenue Calculation (Pandas)
#
# ##### Assuming each item_price (after conversion to float) is for a single quantity of that item, calculate the total revenue generated from all orders. Remember that the quantity column indicates how many of that item_name were ordered in that specific line item.

# %%
print(f"Total Revenue : ", round((df["item_price"] * df["quantity"]).sum(), 2))
# Out:
# Total Revenue :  39237.02
